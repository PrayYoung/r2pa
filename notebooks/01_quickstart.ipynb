# %% [markdown]
# # R2PA Quickstart Notebook
# This notebook runs a minimal end-to-end pipeline (heuristic regime + PPO).

# %%
# !uv run python -m portfolio_rl_agent_lab.data.download

# %%
# !uv run python -m portfolio_rl_agent_lab.data.make_dataset
# !uv run python -m portfolio_rl_agent_lab.text.build_text_features
# !uv run python -m portfolio_rl_agent_lab.llm.build_regime_features

# %%
# !uv run r2pa rl train --algo ppo --timesteps 20000

# %%
# !uv run r2pa rl benchmarks --algo ppo --model artifacts/models/ppo_portfolio
# !uv run r2pa rl diagnostics --algo ppo --model artifacts/models/ppo_portfolio
